# %%
print("Hello World")
# Out:
# Hello World

# %%
from dotenv import load_dotenv
import os
load_dotenv()

# os.getenv('NEWS_API_KEY')
# Out:
# True

# %%
import requests

# Your NewsAPI key
API_KEY = os.getenv('NEWS_API_KEY')

# Base URL
url = "https://newsapi.org/v2/everything"

# Parameters for the request
params = {
    "q": "stock market",       # search query
    "language": "en",          # articles in English
    "sortBy": "publishedAt",   # sort by latest
    "pageSize": 5,             # number of results per request
    "apiKey": API_KEY
}

# Fetch articles
response = requests.get(url, params=params)

# Parse JSON response
if response.status_code == 200:
    data = response.json()

# %%
data
# Out:
# {'status': 'ok',
#  'totalResults': 61175,
#  'articles': [{'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'TERESA CEROJANO Associated Press',
#    'title': 'Asian shares are mixed after stocks add a bit to their records on Wall Street',
#    'description': 'Asian shares are mixed on Friday as investors await a key U.S. inflation report',
#    'url': 'https://abcnews.go.com/Business/wireStory/asian-shares-mixed-after-stocks-add-bit-records-125085949',
#    'urlToImage': 'https://i.abcnewsfe.com/a/bb48fbfa-37bb-4df7-91ac-f21962f8efee/wirestory_f46f70b94fd5d68d4968f23c85944285_16x9.jpg?w=1600',
#    'publishedAt': '2025-08-29T05:58:24Z',
#    'content': 'MANILA, Philippines -- Asian shares were mixed on Friday as investors awaited a key U.S. inflation report and after gains in technology stocks on Wall Street helped propel the market to another all-t… [+3616 chars]'},
#   {'source': {'id': None, 'name': 'ETF Daily News'},
#    'author': 'MarketBeat News',
#    'title': 'MarineMax (NYSE:HZO) Shares Down 4.4% on Insider Selling',
#    'description': 'MarineMax, Inc. (NYSE:HZO – Get Free Report) was down 4.4% on Thursday following insider selling activity. The stock traded as low as $26.53 and last traded at $26.70. Approximately 72,067 shares changed hands during trading, a decline of 79% from the average…',
#    'url': 'https://www.etfdailynews.com/2025/08/29/marinemax-nysehzo-shares-down-4-4-on-insider-selling/',
#    'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/marinemax-inc-logo-1200x675.jpg&w=240&h=240&zc=2',
#    'publishedAt': '2025-08-29T05:56:44Z',
#    'content': 'MarineMax, Inc. (NYSE:HZO – Get Free Report) was down 4.4% on Thursday following insider selling activity. The stock traded as low as $26.53 and last traded at $26.70. Approximately 72,067 shares cha… [+4716 chars]'},
#   {'source': {'id': None, 'name': 'ETF Daily News'},
#    'author': 'MarketBeat News',
#    'title': 'Analysts Issue Forecasts for U.S. GoldMining FY2026 Earnings',
#    'description': 'U.S. GoldMining Inc. (NASDAQ:USGO – Free Report) – HC Wainwright issued their FY2026 EPS estimates for U.S. GoldMining in a report released on Tuesday, August 26th. HC Wainwright analyst H. Ihle forecasts that the company will post earnings of ($0.47) per sha…',
#    'url': 'https://www.etfdailynews.com/2025/08/29/analysts-issue-forecasts-for-u-s-goldmining-fy2026-earnings/',
#    'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/us-goldmining-inc-logo-1200x675.jpg?v=20250206122331&w=240&h=240&zc=2',
#    'publishedAt': '2025-08-29T05:56:44Z',
#    'content': 'U.S. GoldMining Inc. (NASDAQ:USGO – Free Report) – HC Wainwright issued their FY2026 EPS estimates for U.S. GoldMining in a report released on Tuesday, August 26th. HC Wainwright analyst H. Ihle fore… [+2957 chars]'},
#   {'source': {'id': None, 'name': 'ETF Daily News'},
#    'author': 'MarketBeat News',
#    'title': 'WANG & LEE GROUP (NASDAQ:WLGS) Shares to Reverse Split on Tuesday, September 2nd',
#    'description': 'Shares of WANG & LEE GROUP, Inc. (NASDAQ:WLGS – Free Report) are going to reverse split before the market opens on Tuesday, September 2nd. The 1-250 reverse split was announced on Thursday, August 21st. The number of shares owned by shareholders will be adjus…',
#    'url': 'https://www.etfdailynews.com/2025/08/29/wang-lee-group-nasdaqwlgs-shares-to-reverse-split-on-tuesday-september-2nd/',
#    'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/wang--lee-group-inc-logo-1200x675.jpg?v=20230612151526&w=240&h=240&zc=2',
#    'publishedAt': '2025-08-29T05:56:44Z',
#    'content': 'Shares of WANG &amp; LEE GROUP, Inc. (NASDAQ:WLGS – Free Report) are going to reverse split before the market opens on Tuesday, September 2nd. The 1-250 reverse split was announced on Thursday, Augus… [+1810 chars]'},
#   {'source': {'id': None, 'name': 'ETF Daily News'},
#    'author': 'MarketBeat News',
#    'title': 'Hudson Pacific Properties (NYSE:HPP) Shares Down 4.4% After Analyst Downgrade',
#    'description': 'Hudson Pacific Properties, Inc. (NYSE:HPP – Get Free Report)’s stock price was down 4.4% on Thursday after Wells Fargo & Company lowered their price target on the stock from $3.40 to $3.10. Wells Fargo & Company currently has an overweight rating on the stock…',
#    'url': 'https://www.etfdailynews.com/2025/08/29/hudson-pacific-properties-nysehpp-shares-down-4-4-after-analyst-downgrade/',
#    'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/hudson-pacific-properties-inc-logo-1200x675.png?v=20250630114546&w=240&h=240&zc=2',
#    'publishedAt': '2025-08-29T05:56:44Z',
#    'content': 'Hudson Pacific Properties, Inc. (NYSE:HPP – Get Free Report)’s stock price was down 4.4% on Thursday after Wells Fargo &amp; Company lowered their price target on the stock from $3.40 to $3.10. Wells… [+6304 chars]'}]}

# %%
from google_news_feed import GoogleNewsFeed

gnf = GoogleNewsFeed(language='en',country='US')
results = gnf.query("python")
print(results)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 4
#       1 from google_news_feed import GoogleNewsFeed
#       3 gnf = GoogleNewsFeed(language='en',country='US')
# ----> 4 results = gnf.query("python")
#       5 print(results)
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google_news_feed\__init__.py:193, in GoogleNewsFeed.query(self, query, before, after, when)
#     188 """
#     189 For more information on the parameters, see:
#     190 https://newscatcherapi.com/blog/google-news-rss-search-parameters-the-missing-documentaiton
#     191 """
#     192 url = GoogleNewsFeed._build_query_url(query,self.country,self.language,before,after,when)
# --> 193 return self._get_feed(url)
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google_news_feed\__init__.py:169, in GoogleNewsFeed._get_feed(self, url)
#     167 if self.resolve_internal_links:
#     168     if self.run_async:
# --> 169         items = asyncio.run(self._async_resolve_internal_links(items))
#     170     else:
#     171         items = self._resolve_internal_links(items)
#
# File ~\anaconda3\envs\stocksnap\Lib\asyncio\runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
gnf = GoogleNewsFeed(language='en',country='US')
results = gnf.top_headlines()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 gnf = GoogleNewsFeed(language='en',country='US')
# ----> 2 results = gnf.top_headlines()
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google_news_feed\__init__.py:185, in GoogleNewsFeed.top_headlines(self)
#     183 def top_headlines(self)->list[NewsItem]:
#     184     url = f"{BASE_URL}?{GoogleNewsFeed._build_ceid(self.country,self.language)}"
# --> 185     return self._get_feed(url)
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google_news_feed\__init__.py:169, in GoogleNewsFeed._get_feed(self, url)
#     167 if self.resolve_internal_links:
#     168     if self.run_async:
# --> 169         items = asyncio.run(self._async_resolve_internal_links(items))
#     170     else:
#     171         items = self._resolve_internal_links(items)
#
# File ~\anaconda3\envs\stocksnap\Lib\asyncio\runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
# testing tavily search
print("ALL GoOD")
# Out:
# ALL GoOD

# %%
pip install -qU langchain-tavily
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
print(os.getenv('TAVILY_API_KEY')[:5])
# Out:
# tvly-

# %%
from langchain_tavily import TavilySearch
tool = TavilySearch(
    max_results=5,
    topic="general",
    # include_answer=False,
    # include_raw_content=False,
    # include_images=False,
    # include_image_descriptions=False,
    # search_depth="basic",
    time_range="day",
    # include_domains=None,
    # exclude_domains=None
)

# %%
response= tool.invoke({"query": "Tell me about latest news about tatasteel"})

# %%
response
# Out:
# {'query': 'Tell me about latest news about tatasteel',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.livemint.com/tata-steel/news/companyid-s0003026',
#    'title': 'Tata Steel News - Mint',
#    'content': "Stay Informed with our up-to-date coverage of Tata Steel's latest news and developments. Stay in loop with Tata Steel's latest news updates.",
#    'score': 0.77199864,
#    'raw_content': None},
#   {'url': 'https://www.msn.com/en-in/money/markets/tata-steel-under-pressure-sebi-analyst-flags-bearish-momentum-despite-long-term-strength/ar-AA1LnsdO',
#    'title': 'SEBI Analyst Flags Bearish Momentum Despite Long-Term Strength',
#    'content': 'Tata Steel is under pressure as weak global demand and technical weakness weigh on the stock. SEBI-registered analyst Deepak Pal noted that the stock is',
#    'score': 0.5837973,
#    'raw_content': None},
#   {'url': 'https://ommcomnews.com/odisha-news/tata-steel-foundation-inks-mou-with-odisha-govt-to-promote-inclusive-urban-habitats/',
#    'title': 'Tata Steel Foundation Inks MoU With Odisha Govt To Promote ...',
#    'content': 'Bhubaneswar: Tata Steel Foundation has signed a Memorandum of Understanding (MoU) with the Housing & Urban Development (H&UD) Department to promote',
#    'score': 0.5798055,
#    'raw_content': None},
#   {'url': 'https://www.moneycontrol.com/india/stockpricequote/ironsteel/tatasteel/TIS',
#    'title': 'Tata Steel Ltd. - Share/Stock Price - Moneycontrol',
#    'content': 'Tata Steel Share Price: Find the latest news on Tata Steel Stock Price. Get all the information on Tata Steel with historic price charts for NSE / BSE.',
#    'score': 0.57780564,
#    'raw_content': None},
#   {'url': 'https://www.msn.com/en-in/money/markets/us-tariff-will-not-have-much-impact-on-domestic-steel-sector-tata-steel-ceo-t-v-narendran/ar-AA1Llevf',
#    'title': 'US tariff will not have much impact on domestic steel sector - MSN',
#    'content': 'Tata Steel CEO T V Narendran stated that the US tariff of 50% is unlikely to significantly affect the domestic steel sector, though its European operations',
#    'score': 0.5081298,
#    'raw_content': None}],
#  'response_time': 1.24,
#  'request_id': '46f9ed5d-2138-4865-9891-370024c52cbe'}

# %%
response.keys()
# Out:
# dict_keys(['query', 'follow_up_questions', 'answer', 'images', 'results', 'response_time', 'request_id'])

# %%
print(response['results'])
# Out:
# [{'url': 'https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms', 'title': 'Tata Steel Share Price - Stocks', 'content': '[24 Hours Left: 50% OFF!](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms) *   [TECHNICALS](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms#technicalInsights "TECHNICALS") *   [News](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms#newsAnalysis "News") *   [Analysis](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms#research "Analysis") *   [Recos](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms#recommendations "Recos") *   [Financials](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms#financials "Financials") *   [Technicals](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms#technicalInsights "Technicals") *   [About](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms#stocksAbout "About") *   [Income (P&L)](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms#financialsIncome "Income (P&L)") *   [Ratios](https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms#financialsRatios "Ratios") | Basic EPS (₹) | 2.74 | -3.62 | 7.17 | 332.35 | 63.78 [...]ndiatimes.com/markets/live-coverage "Go to Share Market Live Page")[Bajaj Housing Finance Share Price](https://economictimes.indiatimes.com/bajaj-housing-finance-ltd/stocks/companyid-60813.cms "Go to Bajaj Housing Finance Share Price Page")[TCS Q4 Results](https://economictimes.indiatimes.com/markets/stocks/live-blog/tcs-q4-results-live-updates-tcs-q4-earnings-revenue-profit-loss-fy24-latest-news-12-april-2024/liveblog/109233363.cms "Go to TCS Q4 Results Page")[Adani Green Q2 Results](https://economictimes.indiatimes.com/markets/stocks/earnings/adani-green-q2-results-cons-pat-surges-2-5-times-to-rs-372-crore-revenue-up-40-yoy/articleshow/104820829.cms "Go to Adani Green Q2 Results Page")[Maruti Suzuki Q2 Results](https://economictimes.indiatimes.com/markets/stocks/earnings/maruti-suzuki-q2-results-net-profit-zooms-80-yoy-to-rs-3716-crore-beats-estimate/articleshow/104750045.cms "Go to Maruti Suzuki Q2 Results Page")[Cipla Q2 Results](https://economictimes.indiatimes.com/markets/stocks/earnings/cipla-q2-results-profit-jumps-43-yoy-to-rs-1131-crore-revenue-rises-15/articleshow/104750107.cms "Go to Cipla Q2 Results Page")[Mamaearth IPO](https://economictimes.indiatimes.com/markets/ipos/fpos/mamaearth-ipo-to-open-on-october-31-price-band-announced/articleshow/104713653.cms "Go to Mamaearth IPO Page")[Nestle India Q3 Results](https://economictimes.indiatimes.com/markets/stocks/earnings/nestle-india-q3-results-profit-surges-37-yoy-to-rs-908-crore-firm-declares-rs-140-per-share-interim-dividend/articleshow/104544457.cms "Go to Nestle India Q3 Results Page")', 'score': 0.71113056, 'raw_content': None}, {'url': 'https://www.livemint.com/market/market-stats/stocks-tata-steel-share-price-nse-bse-s0003026', 'title': 'Tata Steel Share Price Today 29 Aug 2025', 'content': '[View Market Dashboard](https://www.livemint.com/market/market-stats) *   [Home](https://www.livemint.com/) *   [Markets](https://www.livemint.com/market) *   [Market News](https://www.livemint.com/market) *   [IPO](https://www.livemint.com/market/ipo) *   [Bonds](https://www.livemint.com/market/bonds) *   [Commodities](https://www.livemint.com/market/commodities) *   [Cryptocurrency](https://www.livemint.com/market/cryptocurrency) *   [Market Data](https://www.livemint.com/market/market-stats/stocks-tata-steel-share-price-nse-bse-s0003026) *   [Stock Pages](https://www.livemint.com/market/market-stats) *   [Index pages](https://www.livemint.com/market/india-indices) *   [Bullion](https://www.livemint.com/market/market-stats/stocks-tata-steel-share-price-nse-bse-s0003026) *   [Gold](https://www.livemint.c ...

# %%
pip install langgraph
# Out:
# Collecting langgraph
#   Using cached langgraph-0.6.6-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langgraph) (0.3.75)
# Collecting langgraph-checkpoint<3.0.0,>=2.1.0 (from langgraph)
#   Using cached langgraph_checkpoint-2.1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<0.7.0,>=0.6.0 (from langgraph)
#   Using cached langgraph_prebuilt-0.6.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph)
#   Downloading langgraph_sdk-0.2.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langgraph) (2.11.7)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Using cached xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph)
#   Using cached ormsgpack-1.10.0-cp312-cp312-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.3)
# Requirement already satisfied: anyio in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (4.10.0)
# Requirement already satisfied: certifi in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.16.0)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langchain-core>=0.1->langgraph) (0.4.20)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\302sy\anaconda3\envs\stocksnap\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.3.0)
# Using cached langgraph-0.6.6-py3-none-any.whl (153 kB)
# Using cached langgraph_checkpoint-2.1.1-py3-none-any.whl (43 kB)
# Using cached langgraph_prebuilt-0.6.4-py3-none-any.whl (28 kB)
# Downloading langgraph_sdk-0.2.4-py3-none-any.whl (53 kB)
# Using cached ormsgpack-1.10.0-cp312-cp312-win_amd64.whl (121 kB)
# Using cached xxhash-3.5.0-cp312-cp312-win_amd64.whl (30 kB)
# Installing collected packages: xxhash, ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph
#
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#    -------------------------- ------------- 4/6 [langgraph-prebuilt]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    ---------------------------------------- 6/6 [langgraph]
#
# Successfully installed langgraph-0.6.6 langgraph-checkpoint-2.1.1 langgraph-prebuilt-0.6.4 langgraph-sdk-0.2.4 ormsgpack-1.10.0 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.chat_models import init_chat_model

llm= init_chat_model(model="gpt-4o-mini", model_provider="openai")

# %%
llm.invoke("test")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CAfZo7t068Y9MhjnNP12yY1HSL38i', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--41c84137-6922-4fc2-9448-25afa480f8ed-0', usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_tavily import TavilySearch
from langgraph.prebuilt import create_react_agent
from langchain.chat_models import init_chat_model

llm= init_chat_model(model="gpt-4o-mini", model_provider="openai")

# Initialize Tavily Search Tool
tavily_search_tool = TavilySearch(
    max_results=5,
    topic="general",
)

agent = create_react_agent(llm, [tavily_search_tool])

user_input = "Can you summarize the latest news about TATASTEEL in 3 points along with the date articles published. sentiment score or just a hint like negative, positive or neutral. "

for step in agent.stream(
    {"messages": user_input},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Can you summarize the latest news about TATASTEEL in 3 points along with the date articles published. sentiment score or just a hint like negative, positive or neutral.
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (call_6fhrdoZm31J5DBc33MXbMEQ0)
#  Call ID: call_6fhrdoZm31J5DBc33MXbMEQ0
#   Args:
#     query: TATASTEEL news
#     time_range: week
#     topic: news
#     search_depth: advanced
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "TATASTEEL news", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://economictimes.indiatimes.com/tata-steel-ltd/stocksupdate/companyid-12902.cms", "title": "Tata Steel News", "content": "Published Time: Fri, 29 Aug 2025 05:50:34 GMT\n\nTata Steel News - Tata Steel Announcement, Latest News on Tata Steel - The Economic Times\n\nBenchmarkslive\n\nSensex80,209.17 128.60\n\nFEATURED FUNDS ★★★★★ HSBC Large Cap Fund Direct-Growth 5Y Return 17.73 % Invest NowFEATURED FUNDS ★★★★★ UTI Aggressive Hybrid Fund Regular Plan-Growth 5Y Return 18.69 % Invest Now\n\nEnter search text: \n\nImage 1: The Economic TimesImage 2: ET Markets [...] Share Holding\n\nTata Steel News\n\n\n\nAll News Announcement Recos\n\nBSE LIVE\n\n11:25 | 29-08-2025\n\n154.90\n\nChange:\n\n1.35(0.87%)\n\nVolume:\n\n214,878\n\nOpen:\n\n154.25\n\nPrv. Close:\n\n153.55\n\nToday:\n\n153.00\n\nImage 3: Tata Steel Ltd.\n\n155.20\n\n52-Wk:\n\n122.60\n\nImage 4: Tata Steel Ltd.\n\n170.20\n\nBid:\n\n154.75(1774)\n\nOffer:\n\n155.10(111790)\n\nNSE LIVE\n\n11:23 | 29-08-2025\n\n154.72\n\nChange:\n\n1.10(0.71%)\n\nVolume:\n\n6,703,595\n\nOpen:\n\n154.50\n\nPrv. Close:\n\n153.63\n\nToday:\n\n153.05\n\nImage 5: Tata Steel Ltd.\n\n155.10\n\n52-Wk: [...] Tata Steel is projected to announce a significant year-on-year increase in Q1FY26 profitability, driven by improved margins in its India business due to higher steel prices and lower coking coal costs. While revenue growth is expected to be modest, losses from European operations are anticipated to decrease because of cost optimization measures, particularly in the Netherlands.\n\n### Tata Steel Announcement under Regulation 30 (LODR)-Newspaper Publication\n\n | Announcement \n\n Regulations, 2015", "score": 0.8319231, "raw_content": null}, {"url": "https://www.india.com/business/amid-tcs-layoffs-good-news-for-tata-steel-employees-announces-bonus-of-rs-3030000000-for-fy25-8042606/", "title": "Amid TCS layoffs in, good news for this Tata company employees ...", "content": "Amid TCS layoffs, good news for this Tata company employees, announces bonus of Rs 3030000000 for…\n\nTata Steel on Thursday said it will distribute a total bonus of Rs 303.13 crore to employees for the financial year 2024-25, after signing a memorandum of settlement with the workers’ union in Jamshedpur.\n\nOf this, Rs 152.44 crore has been earmarked for the Jamshedpur divisions, including the tubes unit, benefiting 11,446 employees, the company added. [...] ### Tata Steel Rs 303.13 crore Bonus For Employees\n\nAccording to the memorandum of settlement signed with Tata Workers’ Union (TWU), the total payout for eligible employees of all applicable divisions and units on account of annual bonus for the year 2024-25 will be Rs 303.13 crore, the company, in a statement, said.\n\n### Also Read\n\n ### Meet journalist, who laid foundation of Tata Steel and Tata Power and mortgaged his wife's jewellery to save…, he is…", "score": 0.767429, "raw_content": null}, {"url": "https://www.livemint.com/tata-steel/news/companyid-s0003026", "title": "Tata Steel News", "content": "Tata Steel News: Find Tata Steel News Today, Latest News Tata Steel\n\nImage 2: menu\n\nEnglish\n\nImage 3: mint\n\nImage 4: epaperSubscribee-paperSign in\n\nThursday, 28 August 2025\n\n   Home\n   Latest News\n   Markets\n   News\n   Premium\n   Companies\n   Money\n   Delhi Gold Rate\n   IPO\n   Technology\n   Mint Hindi\n   In Charts\n\nWall Street Journal + Mintat flat 1500 offSubscribe@1999;)\n\nHello User\n\nSign in\n\nSign Out\n\nMy Account\n\n   Subscribe\n   My Watchlist\n   Newsletters\n   My Vouchers\n   Notifications [...] Thu Aug 28 2025 05:02:331. Interglobe Aviation share price 2. ₹5,793.10-4.16%1. Bharat Electronics share price 2. ₹366.00 0.04%1. Vedanta share price 2. ₹425.70-0.60%1. Tata Power Co share price 2. ₹374.80-0.83%1. Indian Oil Corp share price 2. ₹139.15 0.11%\n\nBusiness News/Market/Market Stats/Tata Steel share price/ Tata Steel ...
# ================================== Ai Message ==================================
#
# Here are the latest news updates on TATASTEEL:
#
# 1. **Quarterly Profitability Expected to Rise**
#    - **Summary**: Tata Steel is anticipated to report a significant year-on-year increase in profitability for Q1FY26, primarily attributed to improved margins in its India operations due to rising steel prices and reduced coking coal costs. Revenue growth is expected to be modest, but losses from European operations may decrease following cost optimization initiatives.
#    - **Published**: August 29, 2025
#    - **Sentiment**: Positive
#    - [Read more](https://economictimes.indiatimes.com/tata-steel-ltd/stocksupdate/companyid-12902.cms)
#
# 2. **Bonus Distribution for Employees**
#    - **Summary**: Tata Steel has announced a total bonus payout of Rs 303.13 crore for its employees for the financial year 2024-25. This decision follows a memorandum of settlement signed with the Tata Workers’ Union and will benefit over 11,000 employees.
#    - **Published**: August 28, 2025
#    - **Sentiment**: Positive
#    - [Read more](https://www.india.com/business/amid-tcs-layoffs-good-news-for-tata-steel-employees-announces-bonus-of-rs-3030000000-for-fy25-8042606/)
#
# 3. **Investment in Subsidiary**
#    - **Summary**: Tata Steel has invested USD 355 million in its subsidiary, T Steel Holdings Pte. Ltd., by acquiring equity shares, which strengthens the capital base of the subsidiary. This move follows previous disclosures regarding its financial commitments.
#    - **Published**: August 28, 2025
#    - **Sentiment**: Positive
#    - [Read more](https://www.angelone.in/news/market-updates/tata-steel-share-price-in-focus-invests-usd-355-million-in-t-steel-holdings)
#
# These entries reflect a generally positive sentiment regarding Tata Steel's recent developments and financial performance.

# %%
from langchain import hub
prompt = hub.pull("rlm/rag-prompt")

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})])

# %%
 # get the document and load to vectordatabase
from langchain.chat_models import init_chat_model
from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
from langchain_core.vectorstores import InMemoryVectorStore
from langchain_community.document_loaders import PyPDFLoader
from dotenv import load_dotenv
load_dotenv()
from langchain import hub
from langchain_text_splitters import RecursiveCharacterTextSplitter


doc = "S:\\Generative AI\\StockSnapAI\\data\\4259054b-0c8e-4eaf-950a-56b318b34256.pdf"
embedding= GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001" )
vector_store = InMemoryVectorStore(embedding=embedding)

# Load and chunk contents of the blog
loader = PyPDFLoader(doc)
docs = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
all_splits = text_splitter.split_documents(docs)

# Index chunks
_ = vector_store.add_documents(documents=all_splits)

llm= init_chat_model(model= 'gemini-2.0-flash', model_provider="google_genai")

prompt = hub.pull("rlm/rag-prompt")

question = "Can you answer the latest things that are doing by TATASTEEL for sure."

retrieved_docs = vector_store.similarity_search(question)
docs_content = "\n\n".join(doc.page_content for doc in retrieved_docs)
prompt = prompt.invoke({"question": question, "context": docs_content})
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\langchain_google_genai\embeddings.py:243, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     242 try:
# --> 243     result = self.client.batch_embed_contents(
#     244         BatchEmbedContentsRequest(requests=requests, model=self.model)
#     245     )
#     246 except Exception as e:
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1437, in GenerativeServiceClient.batch_embed_contents(self, request, model, requests, retry, timeout, metadata)
#    1436 # Send the request.
# -> 1437 response = rpc(
#    1438     request,
#    1439     retry=retry,
#    1440     timeout=timeout,
#    1441     metadata=metadata,
#    1442 )
#    1444 # Done; return the response.
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[3], line 24
#      21 all_splits = text_splitter.split_documents(docs)
#      23 # Index chunks
# ---> 24 _ = vector_store.add_documents(documents=all_splits)
#      26 llm= init_chat_model(model= 'gemini-2.0-flash', model_provider="google_genai")
#      28 prompt = hub.pull("rlm/rag-prompt")
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\langchain_core\vectorstores\in_memory.py:195, in InMemoryVectorStore.add_documents(self, documents, ids, **kwargs)
#     193 """Add documents to the store."""
#     194 texts = [doc.page_content for doc in documents]
# --> 195 vectors = self.embedding.embed_documents(texts)
#     197 if ids and len(ids) != len(texts):
#     198     msg = (
#     199         f"ids must be the same length as texts. "
#     200         f"Got {len(ids)} ids and {len(texts)} texts."
#     201     )
#
# File ~\anaconda3\envs\stocksnap\Lib\site-packages\langchain_google_genai\embeddings.py:247, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     243         result = self.client.batch_embed_contents(
#     244             BatchEmbedContentsRequest(requests=requests, model=self.model)
#     245         )
#     246     except Exception as e:
# --> 247         raise GoogleGenerativeAIError(f"Error embedding content: {e}") from e
#     248     embeddings.extend([list(e.values) for e in result.embeddings])
#     249 return embeddings
#
# GoogleGenerativeAIError: Error embedding content: 429 Resource has been exhausted (e.g. check quota).

# %%
print("OK")
# Out:
# OK

# %%
import sys
import os

# %%
colors = {
            "STRONG POSITIVE": "#00C851",
            "POSITIVE": "#4CAF50",
            "NEUTRAL": "#FFA726",
            "NEGATIVE": "#F44336",
            "STRONG NEGATIVE": "#B71C1C"
        }

# %%
colors.get("STRONG POSIasdfTIVE", "#808080")
# Out:
# '#808080'

# %%
import os

# %%
os.path.join(os.getcwd(), "logs")
