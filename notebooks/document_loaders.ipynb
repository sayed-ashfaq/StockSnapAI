# %%
print("helo world")
# Out:
# helo world

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain_community.document_loaders import UnstructuredExcelLoader

# %%
from langchain.document_loaders import PyPDFLoader
import fitz  # PyMuPDF for images

# Load PDF text
loader = PyPDFLoader("C:\\Users\\302sy\\Desktop\\Generative AI\\StockSnapAI\\data\\4259054b-0c8e-4eaf-950a-56b318b34256.pdf")
text_docs = loader.load()

# Extract images
doc = fitz.open("C:\\Users\\302sy\\Desktop\\Generative AI\\StockSnapAI\\data\\4259054b-0c8e-4eaf-950a-56b318b34256.pdf")
images = []
for page_index in range(len(doc)):
    for img_index, img in enumerate(doc[page_index].get_images(full=True)):
        base_image = doc.extract_image(img[0])
        images.append(base_image["image"])  # raw image bytes
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 from langchain.document_loaders import PyPDFLoader
# ----> 2 import fitz  # PyMuPDF for images
#       4 # Load PDF text
#       5 loader = PyPDFLoader("C:\\Users\\302sy\\Desktop\\Generative AI\\StockSnapAI\\data\\4259054b-0c8e-4eaf-950a-56b318b34256.pdf")
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\fitz\__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\frontend\__init__.py:1
# ----> 1 from .events import *
#       2 from . import config
#       3 from .components import *
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\frontend\events\__init__.py:1
# ----> 1 from .clipboard import *
#       2 from .event_mixins import *
#       3 from .hash_change import *
#
# ...

# %%
import fitz  # PyMuPDF
from langchain_core.documents import Document
from PIL import Image
import numpy as np
from langchain.chat_models import init_chat_model
from langchain.prompts import PromptTemplate
from langchain.schema.messages import HumanMessage
import os
import base64
import io
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS

# %%
pdf_path= "C:\\Users\\302sy\\Desktop\\Generative AI\\StockSnapAI\\data\\4259054b-0c8e-4eaf-950a-56b318b34256.pdf"

doc= fitz.open(pdf_path)
all_docs= []
all_embeddings=[]
image_data_store= {}

# text splitter
splitter= RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=200)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 pdf_path= "C:\\Users\\302sy\\Desktop\\Generative AI\\StockSnapAI\\data\\4259054b-0c8e-4eaf-950a-56b318b34256.pdf"
# ----> 3 doc= fitz.open(pdf_path)
#       4 all_docs= []
#       5 all_embeddings=[]
#
# AttributeError: module 'fitz' has no attribute 'open'
