# %%
print("helo world")
# Out:
# helo world

# %%
pdf_path= "C:\\Users\\302sy\\Desktop\\Generative AI\\StockSnapAI\\data\\multimodal_sample.pdf"

# %%
import fitz
from langchain_core.documents import Document

# %%
doc= fitz.open(pdf_path)
doc
# Out:
# Document('C:\Users\302sy\Desktop\Generative AI\StockSnapAI\data\multimodal_sample.pdf')

# %%
all_docs= []
all_embedding= []
image_data_store= {}

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
splitter= RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=100)

# %%
for i, page in enumerate(doc):
    text= page.get_text()
    print(text)
# Out:
# Annual Revenue Overview
# This document summarizes the revenue trends across Q1, Q2, and Q3. As illustrated in the chart
# below, revenue grew steadily with the highest growth recorded in Q3.
# Q1 showed a moderate increase in revenue as new product lines were introduced. Q2 outperformed
# Q1 due to marketing campaigns. Q3 had exponential growth due to global expansion.

# %%
for i, page in enumerate(doc):
    print(page.get_text())
# Out:
# Annual Revenue Overview
# This document summarizes the revenue trends across Q1, Q2, and Q3. As illustrated in the chart
# below, revenue grew steadily with the highest growth recorded in Q3.
# Q1 showed a moderate increase in revenue as new product lines were introduced. Q2 outperformed
# Q1 due to marketing campaigns. Q3 had exponential growth due to global expansion.

# %%
for i, page in enumerate(doc):
    print(page.get_images(full= True))
# Out:
# [(6, 0, 400, 300, 8, 'DeviceRGB', '', 'I1', 'FlateDecode', 0)]

# %%
doc.extract_image(xref= 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1324\2455659907.py in ?()
# ----> 1 doc.extract_image(xref= 0)
#
# ~\anaconda3\envs\StockSnapAI\Lib\site-packages\pymupdf\__init__.py in ?(self, xref)
#    4133
#    4134         pdf = _as_pdf_document(self)
#    4135
#    4136         if not _INRANGE(xref, 1, mupdf.pdf_xref_len(pdf)-1):
# -> 4137             raise ValueError( MSG_BAD_XREF)
#    4138
#    4139         obj = mupdf.pdf_new_indirect(pdf, xref, 0)
#    4140         subtype = mupdf.pdf_dict_get(obj, PDF_NAME('Subtype'))
#
# ValueError: bad xref

# %%
import hashlib
import mimetypes
from pathlib import Path
from typing import Tuple
import uuid

def generate_document_id(filename: str, file_content: bytes) -> str:
    """Generate unique document ID based on filename and content hash"""
    content_hash = hashlib.md5(file_content).hexdigest()[:8]
    return f"{Path(filename).stem}_{content_hash}_{uuid.uuid4().hex[:8]}"

# def get_file_type(filename: str) -> Tuple[FileType, str]:
#     """Get file type and MIME type from filename"""
#     ext = Path(filename).suffix.lower()
#     mime_type, _ = mimetypes.guess_type(filename)
#
#     type_mapping = {
#         '.pdf': FileType.PDF,
#         '.txt': FileType.TXT,
#         '.docx': FileType.DOCX,
#         '.xlsx': FileType.XLSX,
#         '.csv': FileType.CSV,
#     }
#
#     return type_mapping.get(ext, FileType.TXT), mime_type or 'application/octet-stream'

def format_file_size(size_bytes: int) -> str:
    """Format file size in human readable format"""
    for unit in ['B', 'KB', 'MB', 'GB']:
        if size_bytes < 1024:
            return f"{size_bytes:.1f} {unit}"
        size_bytes /= 1024
    return f"{size_bytes:.1f} TB"

# %%
generate_document_id("ofsasdf.pdf", 200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 generate_document_id("ofsasdf.pdf", 200)
#
# Cell In[19], line 9, in generate_document_id(filename, file_content)
#       7 def generate_document_id(filename: str, file_content: bytes) -> str:
#       8     """Generate unique document ID based on filename and content hash"""
# ----> 9     content_hash = hashlib.md5(file_content).hexdigest()[:8]
#      10     return f"{Path(filename).stem}_{content_hash}_{uuid.uuid4().hex[:8]}"
#
# TypeError: object supporting the buffer API required

# %%
hashlib.md5(480).hexdigest()[:8]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 hashlib.md5(480).hexdigest()[:8]
#
# TypeError: object supporting the buffer API required

# %%
trails = ['add', 'sub', 'mul', 'div', 'root', 'plus']
results= []
for trail in trails:
    if trail == 'add':
        result= 'addition'
    elif trail == 'sub':
        result= "subtraction"
    elif trail == 'mul':
        result= "multiplication"
    elif trail == 'div':
        result= "division"
    else:
        continue
    results.extend(result)

# %%
results
# Out:
# ['a',
#  'd',
#  'd',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  's',
#  'u',
#  'b',
#  't',
#  'r',
#  'a',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  'm',
#  'u',
#  'l',
#  't',
#  'i',
#  'p',
#  'l',
#  'i',
#  'c',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'd',
#  'i',
#  'v',
#  'i',
#  's',
#  'i',
#  'o',
#  'n']

# %%
paths= ["C:\\Users\\302sy\\Desktop\\Generative AI\\StockSnapAI\\data\\multimodal_sample.pdf",
        "C:\\Users\\302sy\\Desktop\\Generative AI\\StockSnapAI\\data\\Response 1 from portfolio sentiment.txt",
        "C:\\Users\\302sy\\Desktop\\Generative AI\\StockSnapAI\\data\\Screenshot 2025-09-03 175720.png"]

# %%
from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader, TextLoader
from langchain_community.document_loaders.image import UnstructuredImageLoader
from typing import List
from pathlib import Path
docs:List= []
for p in paths:
    p=Path(p)
    ext = p.suffix.lower()
    if ext == ".pdf":
        loader = PyPDFLoader(str(p))
    elif ext == ".docx":
        loader = Docx2txtLoader(str(p))
    elif ext == ".txt":
        loader = TextLoader(str(p), encoding="utf-8")
    elif ext == ".png":
        loader = UnstructuredImageLoader(str(p))
    else:
        print("Unsupported extension skipped")
        continue
    docs.extend(loader.load())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 20
#      18     print("Unsupported extension skipped")
#      19     continue
# ---> 20 docs.extend(loader.load())
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\langchain_core\document_loaders\base.py:32, in BaseLoader.load(self)
#      30 def load(self) -> list[Document]:
#      31     """Load data into Document objects."""
# ---> 32     return list(self.lazy_load())
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\langchain_community\document_loaders\unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
#     109     if self.mode == "elements":
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\langchain_community\document_loaders\image.py:49, in UnstructuredImageLoader._get_elements(self)
#      48 def _get_elements(self) -> List:
# ---> 49     from unstructured.partition.image import partition_image
#      51     return partition_image(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\unstructured\partition\image.py:7
#       5 from unstructured.chunking import add_chunking_strategy
#       6 from unstructured.documents.elements import Element, process_metadata
# ----> 7 from unstructured.file_utils.filetype import add_metadata
#       8 from unstructured.partition.common.common import exactly_one
#       9 from unstructured.partition.common.lang import check_language_args
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\unstructured\file_utils\filetype.py:48
#      45 from typing_extensions import ParamSpec
#      47 from unstructured.documents.elements import Element
# ---> 48 from unstructured.file_utils.encoding import detect_file_encoding, format_encoding_str
#      49 from unstructured.file_utils.model import FileType
#      50 from unstructured.logger import logger
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\unstructured\file_utils\encoding.py:3
#       1 from typing import IO, Optional, Tuple, Union
# ----> 3 from charset_normalizer import detect
#       5 from unstructured.errors import UnprocessableEntityError
#       6 from unstructured.partition.common.common import convert_to_bytes
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\charset_normalizer\__init__.py:24
#       2 """
#       3 Charset-Normalizer
#       4 ~~~~~~~~~~~~~~
#    (...)     20 :license: MIT, see LICENSE for more details.
#      21 """
#      22 import logging
# ---> 24 from .api import from_bytes, from_fp, from_path, is_binary
#      25 from .legacy import detect
#      26 from .models import CharsetMatch, CharsetMatches
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\charset_normalizer\api.py:5
#       2 from os import PathLike
#       3 from typing import BinaryIO, List, Optional, Set, Union
# ----> 5 from .cd import (
#       6     coherence_ratio,
#       7     encoding_languages,
#       8     mb_encoding_languages,
#       9     merge_coherence_ratios,
#      10 )
#      11 from .constant import IANA_SUPPORTED, TOO_BIG_SEQUENCE, TOO_SMALL_SEQUENCE, TRACE
#      12 from .md import mess_ratio
#
# File ~\anaconda3\envs\StockSnapAI\Lib\site-packages\charset_normalizer\cd.py:14
#       5 from typing import Counter as TypeCounter, Dict, List, Optional, Tuple
#       7 from .constant import (
#       8     FREQUENCIES,
#       9     KO_NAMES,
#    (...)     12     ZH_NAMES,
#      13 )
# ---> 14 from .md import is_suspiciously_successive_range
#      15 from .models import CoherenceMatches
#      16 from .utils import (
#      17     is_accentuated,
#      18     is_latin,
#    (...)     21     unicode_range,
#      22 )
#
# File src\charset_normalizer\md.py:11
#
# ImportError: cannot import name 'is_cjk_uncommon' from 'charset_normalizer.utils' (C:\Users\302sy\anaconda3\envs\StockSnapAI\Lib\site-packages\charset_normalizer\utils.py)
