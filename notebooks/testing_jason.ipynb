# %%
print("Hello World")
# Out:
# Hello World

# %%
result = {'portfolio_analysis': {'stocks': [{'ticker': 'AAPL', 'recent_news': [{'title': 'Apple Stock (AAPL) Sours as Chinese Rival Huawei Throws Down Smartphone Gauntlet', 'url': "https://www.tipranks.com/news/apple-stock-aapl-sours-as-chinese-rival-huawei-throws-down-smartphone-gauntlet", 'published_date': '2025-09-04', 'summary': 'Apple faces increased competition from Huawei in the smartphone market, impacting market sentiment.'}, {'title': 'What To Expect in Markets This Week: August Inflation Data, Apple iPhone Event', 'url': 'https://www.investopedia.com/what-to-expect-in-markets-this-week-august-inflation-data-apple-iphone-event-updates-from-nvidia-oracle-gamestop-11803381', 'published_date': '2025-09-07', 'summary': 'Apple is set to unveil new iPhone models, affecting market expectations and potential stock movements.'}], 'market_sentiment': 'Moderate Buy consensus based on 16 Buy, 12 Hold and 1 Sell ratings, with a target price of $239.36, indicating upside potential.', 'portfolio_insights': 'While facing competitive pressure, upcoming product launches could position Apple favorably in the market.'}, {'ticker': 'TSLA', 'recent_news': [{'title': "Tesla Bulls Try To Take Wheel As 'Robotaxi' Safety Monitors Move Into Driver's Seat", 'url': 'https://www.investors.com/news/tesla-stock-bulls-driver-seat-robotaxi-safety-monitors/', 'published_date': '2025-09-03', 'summary': 'Tesla stock shows positive momentum as it regains key technical levels, suggesting potential bullish activity.'}, {'title': 'Tesla Registrations Tank 84% in Sweden, But Surge 161% in Spain', 'url': 'https://www.tipranks.com/news/tesla-registrations-tank-84-in-sweden-but-surge-161-in-spain', 'published_date': '2025-09-01', 'summary': 'Significant market fluctuations in vehicle registrations highlight performance variability across regions.'}], 'market_sentiment': 'Hold consensus based on 13 Buys, 14 Holds, and 8 Sells, with an average target price suggesting potential downside risk.', 'portfolio_insights': "Despite mixed registration numbers, Tesla's market presence in Spain could lead to future growth opportunities."}], 'overall_insights': 'The portfolio consists of two key players in the tech and automotive sectors. AAPL anticipates product launches while navigating competitive pressures, whereas TSLA faces regional sales variability. Both stocks present unique opportunities and challenges, emphasizing the need for close monitoring of market trends.'}, 'analysis_status': 'SUCCESS', 'session_id': 'session_20250908140901_a8d18f6a', 'cache_key': 'portfolio_APPL_TSLA'}

# %%
result.get("portfolio_analysis",[])
# Out:
# {'stocks': [{'ticker': 'AAPL',
#    'recent_news': [{'title': 'Apple Stock (AAPL) Sours as Chinese Rival Huawei Throws Down Smartphone Gauntlet',
#      'url': 'https://www.tipranks.com/news/apple-stock-aapl-sours-as-chinese-rival-huawei-throws-down-smartphone-gauntlet',
#      'published_date': '2025-09-04',
#      'summary': 'Apple faces increased competition from Huawei in the smartphone market, impacting market sentiment.'},
#     {'title': 'What To Expect in Markets This Week: August Inflation Data, Apple iPhone Event',
#      'url': 'https://www.investopedia.com/what-to-expect-in-markets-this-week-august-inflation-data-apple-iphone-event-updates-from-nvidia-oracle-gamestop-11803381',
#      'published_date': '2025-09-07',
#      'summary': 'Apple is set to unveil new iPhone models, affecting market expectations and potential stock movements.'}],
# ...

# %%
result.get("analysis_status",[])
# Out:
# 'SUCCESS'

# %%
result.get("portfolio_analysis").get("overall_insights",[])
# Out:
# 'The portfolio consists of two key players in the tech and automotive sectors. AAPL anticipates product launches while navigating competitive pressures, whereas TSLA faces regional sales variability. Both stocks present unique opportunities and challenges, emphasizing the need for close monitoring of market trends.'

# %%
len(result.get("portfolio_analysis").get("stocks",[]))
# Out:
# 2

# %%
stocks_data= result.get("portfolio_analysis").get("stocks",[])

# %%
result.get("portfolio_analysis").get("stocks",[])
# Out:
# [{'ticker': 'AAPL',
#   'recent_news': [{'title': 'Apple Stock (AAPL) Sours as Chinese Rival Huawei Throws Down Smartphone Gauntlet',
#     'url': 'https://www.tipranks.com/news/apple-stock-aapl-sours-as-chinese-rival-huawei-throws-down-smartphone-gauntlet',
#     'published_date': '2025-09-04',
#     'summary': 'Apple faces increased competition from Huawei in the smartphone market, impacting market sentiment.'},
#    {'title': 'What To Expect in Markets This Week: August Inflation Data, Apple iPhone Event',
#     'url': 'https://www.investopedia.com/what-to-expect-in-markets-this-week-august-inflation-data-apple-iphone-event-updates-from-nvidia-oracle-gamestop-11803381',
#     'published_date': '2025-09-07',
#     'summary': 'Apple is set to unveil new iPhone models, affecting market expectations and potential stock movements.'}],
# ...

# %%
for stock_data in stocks_data:
    transformed_stock_data = {
        "symbol": stock_data.get("ticker", "error"),
        "sentiment": stock_data.get("ticker").get("market_sentiment"),
    }

# %%
stocks_data
# Out:
# [{'ticker': 'AAPL',
#   'recent_news': [{'title': 'Apple Stock (AAPL) Sours as Chinese Rival Huawei Throws Down Smartphone Gauntlet',
#     'url': 'https://www.tipranks.com/news/apple-stock-aapl-sours-as-chinese-rival-huawei-throws-down-smartphone-gauntlet',
#     'published_date': '2025-09-04',
#     'summary': 'Apple faces increased competition from Huawei in the smartphone market, impacting market sentiment.'},
#    {'title': 'What To Expect in Markets This Week: August Inflation Data, Apple iPhone Event',
#     'url': 'https://www.investopedia.com/what-to-expect-in-markets-this-week-august-inflation-data-apple-iphone-event-updates-from-nvidia-oracle-gamestop-11803381',
#     'published_date': '2025-09-07',
#     'summary': 'Apple is set to unveil new iPhone models, affecting market expectations and potential stock movements.'}],
# ...

# %%
for stock_data in stocks_data:
    dict= {
        "symbol": stock_data.get("ticker"),
        "sentiment": stock_data.get("market_sentiment"),
        "summary": stock_data.get("portfolio_insights"),
        "impact": stock_data.get("market_sentiment") ,
    }
    print(dict)
# Out:
# {'symbol': 'AAPL', 'sentiment': 'Moderate Buy consensus based on 16 Buy, 12 Hold and 1 Sell ratings, with a target price of $239.36, indicating upside potential.', 'summary': 'While facing competitive pressure, upcoming product launches could position Apple favorably in the market.', 'impact': 'Moderate Buy consensus based on 16 Buy, 12 Hold and 1 Sell ratings, with a target price of $239.36, indicating upside potential.'}
# {'symbol': 'TSLA', 'sentiment': 'Hold consensus based on 13 Buys, 14 Holds, and 8 Sells, with an average target price suggesting potential downside risk.', 'summary': "Despite mixed registration numbers, Tesla's market presence in Spain could lead to future growth opportunities.", 'impact': 'Hold consensus based on 13 Buys, 14 Holds, and 8 Sells, with an average target price suggesting potential downside risk.'}
